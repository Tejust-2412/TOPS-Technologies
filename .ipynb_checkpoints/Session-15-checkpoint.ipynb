# %% [markdown]
# <h3> 1. Use the math module to calculate the square root, factorial, and value of pi for given numbers, and print each result.

# %%
import math 

square_root = math.sqrt(64)
factorial = math.factorial(5)
pi = math.pi
print(f"Square_root | {square_root}")
print(f"Factorial   | {factorial}")
print(f"Pi value    | {pi}")
# Out:
# Square_root | 8.0
# Factorial   | 120
# Pi value    | 3.141592653589793

# %% [markdown]
# <h3 >2.Write a script that lists all files in your current directory using the os module, and prints only those files with a .jpg or .png extension.<br><br><em><strong>Hint:</strong> Use os.listdir() and string methods to filter file names.</em>

# %%
import os 
all_items = os.listdir()

for item in all_items :
    if item.lower().endswith(('.jpg', '.csv')):
        print(f"Found: {item}")
# Out:
# Found: data.csv

# %% [markdown]
# <h3> 3.Create a Python program that accepts a date in 'YYYY-MM-DD' format from the user and displays the day of the week using the datetime module.

# %%
import datetime

def find_day_of_week():
    date_str = input("Enter a date (YYYY-MM-DD): ")
    
    try:
        date_obj = datetime.datetime.strptime(date_str, "%Y-%m-%d")
        day_name = date_obj.strftime("%A")
        
        print(f"The day on {date_str} was/will be: {day_name}")
        
    except ValueError:
        print("Error: Invalid format! Please use YYYY-MM-DD (e.g., 2026-07-08).")

find_day_of_week()
# Out:
# Enter a date (YYYY-MM-DD):  2026-08-18
# The day on 2026-08-18 was/will be: Tuesday

# %% [markdown]
# <h3> 4.Build a simple custom module named insta_utils.py with a function format_follower_count(n) that returns '1.5K' for 1500 and '2.3M' for 2300000. Import and use this function in another script to display formatted counts for 3 sample numbers.

# %%
import insta_utils

sample_numbers = [450, 1500, 2300000]
for followers in sample_numbers:
    display_text = insta_utils.format_follower_count(followers)
    print(f"Raw Count: {followers:<8} -> Display: {display_text}")
# Out:
# Raw Count: 450      -> Display: 450
# Raw Count: 1500     -> Display: 1.5K
# Raw Count: 2300000  -> Display: 2.3M

# %% [markdown]
# <h3>5.Create a new virtual environment using venv, activate it, and install the statistics and requests packages via pip. Then, write a script that uses statistics.mean() to calculate the average of a list of numbers.

# %%
import statistics
import requests 
sales_data = [120, 450, 780, 230, 560, 890]
average_sales = statistics.mean(sales_data)
print(f"Data points: {sales_data}")
print(f"Average: {average_sales}")
# Out:
# Data points: [120, 450, 780, 230, 560, 890]
# Average: 505
