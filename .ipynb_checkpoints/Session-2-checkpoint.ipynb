# %% [markdown]
# <h3> 1.Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.

# %%
user_name = "Tejas Kadam"
fav_app = "Instagram"
daily_usage_hours = 1

print(f"My is {user_name} , My favorite Application is {fav_app} and Daily usage hours {daily_usage_hours}")
# Out:
# My is Tejas Kadam , My favorite Application is Instagram and Daily usage hours 1

# %% [markdown]
# <h3> 2.Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function.

# %%
product_name = "Puma T-Shirt"
price = 4599.05
is_available = True 

print("Product Name: " ,product_name)
print("Data Type : ", type(product_name))

print("Product Price: " ,price)
print("Data Type : ", type(price))

print("Product Is Available : " , is_available)
print("Data Type : ", type(is_available))
# Out:
# Product Name:  Puma T-Shirt
# Data Type :  <class 'str'>
# Product Price:  4599.05
# Data Type :  <class 'float'>
# Product Is Available :  True
# Data Type :  <class 'bool'>

# %% [markdown]
# <h3> 3.Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. Use # for single-line and triple quotes for multi-line comments.

# %%
# SPOTIFY PLAYLIST RECOMMENDATION SYSTEM
print("Single- line Comment : Use it for quick, bite-sized notes placed right above or next to a specific line of code.")
""" 
Song                 Singer Name 
---------------------------------------------
Maaz                |      SAMBATA 
Jo Tere Sang        |      JEET GANNGULI 
Tere Bina           |      A.R RAHMAN
EK Din Tere Raahon  |      PRITAM 
---------------------------------------------
"""

print("Multi-line Comments : Use it when you need to write a long explanation, a detailed introduction, or documentation that spans several lines.")
# Out:
# Single- line Comment : Use it for quick, bite-sized notes placed right above or next to a specific line of code.
# Multi-line Comments : Use it when you need to write a long explanation, a detailed introduction, or documentation that spans several lines.

# %% [markdown]
# <h3>4.Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. Follow Python naming conventions and print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

# %%
order_total = 2412
delivery_region = "Nikol" 
discount_percent  = 5

print(f'Order from {delivery_region} totals ₹ {order_total} with {discount_percent}% discount.')
# Out:
# Order from Nikol totals ₹ 2412 with 5% discount.

# %% [markdown]
# <h3> 5.Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>

# %%
def check_number(num):
    if num > 0:
        print("Positive number hai")  
	print("Done!")                

check_number(5)
# Out:
#   File <string>:4
#     print("Done!")
#                                   ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
def check_number(num):
    if num > 0:
        print("Positive number hai")  
        print("Done!")                

check_number(5)
# Out:
# Positive number hai
# Done!
