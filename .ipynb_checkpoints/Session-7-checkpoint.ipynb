# %% [markdown]
# <h3> 1.Write a Python script that checks if a user's entered age is 18 or above and prints 'Eligible for IPL ticket booking' if true, otherwise prints 'Not eligible'.

# %%
Age = int(input("Enter Your Age : "))
if Age >= 18:
    print('Eligible for IPL ticket booking')
else :
    print('Not Eligible for IPL ticket booking')
# Out:
# Enter Your Age :  18
# Eligible for IPL ticket booking

# %% [markdown]
# <h3>2.Create a Python program that takes the number of followers as input and uses if, elif, and else to print 'Micro Influencer' if followers < 10,000, 'Rising Star' if between 10,000 and 100,000, and 'Celebrity' if above 100,000.

# %%
followers = int(input("Enter Your Instagram Followers : "))
if followers < 10000 :
    print("Micro Influencer")
elif followers < 100000 : 
    print("Rising Star")
else : 
    print("Celebrity")
# Out:
# Enter Your Instagram Followers :  100000
# Celebrity

# %% [markdown]
# <h3> 3.Build a Python script that asks the user for their Zomato order total and prints 'Apply Free Delivery' if total is above 299, 'Add more items for free delivery' if between 200 and 299, else 'Delivery charges apply'.

# %%
Total = int(input("Enter Your Total order Amount : "))
if Total > 299 :
    print("Apply Free Delivery")
elif Total >= 200 and Total < 299 :
    print("Add more items for free delivery")
else :
    print("Delivery charges apply")
# Out:
# Enter Your Total order Amount :  250
# Add more items for free delivery

# %% [markdown]
# <h3> 4.Write a Python program using nested if statements: take a user's entered Flipkart cart value and payment method ('UPI', 'Card', 'Cash'). If the cart value is above 1000 and payment method is 'UPI', print 'Eligible for 10% cashback'; if above 1000 and payment is not 'UPI', print 'Eligible for 5% cashback'; else print 'No cashback'.

# %%
Value = int(input("Enter Your Flipkart cart Values : "))
Payment_method = str(input("Enter Your Payment Method : ")).upper()

if Value > 1000 :
    if Payment_method == "UPI" :
        print("Eligible for 10% cashback")
    else :
        print("Eligible for 5% cashback")
else :
    print("No cashback")
# Out:
# Enter Your Flipkart cart Values :  10000
# Enter Your Payment Method :  upi
# Eligible for 10% cashback
